# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install import-ipynb
# %cd /content/drive/My\ Drive/Colab\ Notebooks/RetinaSmartCamera/notebooks
# Out:
# Mounted at /content/drive
# ...
#   Created wheel for import-ipynb: filename=import_ipynb-0.1.3-cp37-none-any.whl size=2976 sha256=dc58110279ab7aca8c0e8ea0d02bb5193d65742064d409f52ecadef4a8fdafc1
#   Stored in directory: /root/.cache/pip/wheels/b4/7b/e9/a3a6e496115dffdb4e3085d0ae39ffe8a814eacc44bbf494b5
# Successfully built import-ipynb
# ...
# /content/drive/My Drive/Colab Notebooks/RetinaSmartCamera/notebooks

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
import cv2
import os

# %%
class MotionDataset(Dataset):
    def __init__(self, frames, img_type, nt):
        data_dir = os.path.join('/content/drive/My Drive/Personal Dataset/Frames/train/Gargoyle', img_type)
        frames = []
        for frame in os.listdir(data_dir):
            frames.append(os.path.join(data_dir, frame))
        self.frames = frames
        self.nt = nt
        self.possible_starts = [i for i in range(len(self.frames)-self.nt)]
        self.img_type = img_type

        data_dir = '/content/drive/My Drive/Personal Dataset/Frames/train'
        sources = []
        for i, obj in enumerate(os.listdir(data_dir)):
            for frame in os.listdir(os.path.join(data_dir,obj)):


    def __getitem__(self, index):
        i = self.possible_starts[index]
        frame_paths = self.frames[i:i+self.nt]
        sequence = torch.ones(self.nt,3,257,490)
        for i, frame_path in enumerate(frame_paths):
            image = cv2.imread(frame_path)/255.0
            image = torch.from_numpy(image.astype('float32')).permute(2,0,1)
            sequence[i]=image

        return sequence
    
    def __len__(self):
        return len(self.frames)
